# %%
from qiime2 import Artifact
from qiime2 import Metadata
import qiime2.plugins.dada2.actions as dada2_actions
import qiime2.plugins.demux.actions as demux_actions
import qiime2.plugins.feature_classifier.actions as feature_classifier_actions
import qiime2.plugins.feature_table.actions as feature_table_actions
import qiime2.plugins.longitudinal.actions as longitudinal_actions
import qiime2.plugins.taxa.actions as taxa_actions

# %%
from urllib import request

url = 'https://docs.qiime2.org/2021.11/data/tutorials/moving-pictures-usage/sample-metadata.tsv'
fn = 'sample-metadata.tsv'
request.urlretrieve(url, fn)
sample_metadata_md = Metadata.load(fn)

# %%
import zipfile

url = 'https://docs.qiime2.org/2021.11/data/tutorials/moving-pictures-usage/emp-single-end-sequences.zip'
fn = 'emp-single-end-sequences.zip'
request.urlretrieve(url, fn)
with zipfile.ZipFile(fn) as zf:
    zf.extractall('emp-single-end-sequences')

# %%
per_sample_sequences_0 = Artifact.import_data(
    'EMPSingleEndSequences',
    'emp-single-end-sequences',
)

# %%
barcodes_sequence_mdc = sample_metadata_md.get_column('barcode-sequence')
per_sample_sequences_0, _ = demux_actions.emp_single(
    seqs=per_sample_sequences_0,
    barcodes=barcodes_sequence_mdc,
    golay_error_correction=True,
    rev_comp_barcodes=False,
    rev_comp_mapping_barcodes=True,
)
table_0, representative_sequences_0, _ = dada2_actions.denoise_single(
    demultiplexed_seqs=per_sample_sequences_0,
    trunc_len=120,
    trim_left=0,
    max_ee=2.0,
    trunc_q=2,
    pooling_method='independent',
    chimera_method='consensus',
    min_fold_parent_over_abundance=1.0,
    n_threads=0,
    n_reads_learn=1000000,
    hashed_feature_ids=True,
)
# Out:
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-yfblax17/a934768e-91cb-4092-a7ff-b0ee724d1289/data /tmp/tmp39vi1zn3/output.tsv.biom /tmp/tmp39vi1zn3/track.tsv /tmp/tmp39vi1zn3 120 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# R version 4.1.1 (2021-08-10)
# Loading required package: Rcpp
# DADA2: 1.22.0 / Rcpp: 1.0.7 / RcppParallel: 5.1.4
# 1) Filtering .
# 2) Learning Error Rates
# 3960 total bases in 33 reads from 1 samples will be used for learning the error rates.
# 3) Denoise samples .
# 4) Remove chimeras (method = consensus)
# 5) Report read numbers through the pipeline
# 6) Write output

# %%
import pandas as pd
sample_metadata_md.to_dataframe()
# Out:
#           barcode-sequence   body-site    year  month   day    subject  \
# sample-id
# L1S8          AGCTGACTAGTC         gut  2008.0   10.0  28.0  subject-1
# L1S57         ACACACTATGGC         gut  2009.0    1.0  20.0  subject-1
# L1S76         ACTACGTGTGGT         gut  2009.0    2.0  17.0  subject-1
# L1S105        AGTGCGATGCGT         gut  2009.0    3.0  17.0  subject-1
# L2S155        ACGATGCGACCA   left palm  2009.0    1.0  20.0  subject-1
# L2S175        AGCTATCCACGA   left palm  2009.0    2.0  17.0  subject-1
# L2S204        ATGCAGCTCAGT   left palm  2009.0    3.0  17.0  subject-1
# L2S222        CACGTGACATGT   left palm  2009.0    4.0  14.0  subject-1
# L3S242        ACAGTTGCGCGA  right palm  2008.0   10.0  28.0  subject-1
# L3S294        CACGACAGGCTA  right palm  2009.0    1.0  20.0  subject-1
# L3S313        AGTGTCACGGTG  right palm  2009.0    2.0  17.0  subject-1
# L3S341        CAAGTGAGAGAG  right palm  2009.0    3.0  17.0  subject-1
# L3S360        CATCGTATCAAC  right palm  2009.0    4.0  14.0  subject-1
# L5S104        CAGTGTCAGGAC      tongue  2008.0   10.0  28.0  subject-1
# L5S155        ATCTTAGACTGC      tongue  2009.0    1.0  20.0  subject-1
# L5S174        CAGACATTGCGT      tongue  2009.0    2.0  17.0  subject-1
# L5S203        CGATGCACCAGA      tongue  2009.0    3.0  17.0  subject-1
# L5S222        CTAGAGACTCTT      tongue  2009.0    4.0  14.0  subject-1
# L1S140        ATGGCAGCTCTA         gut  2008.0   10.0  28.0  subject-2
# L1S208        CTGAGATACGCG         gut  2009.0    1.0  20.0  subject-2
# L1S257        CCGACTGAGATG         gut  2009.0    3.0  17.0  subject-2
# L1S281        CCTCTCGTGATC         gut  2009.0    4.0  14.0  subject-2
# L2S240        CATATCGCAGTT   left palm  2008.0   10.0  28.0  subject-2
# L2S309        CGTGCATTATCA   left palm  2009.0    1.0  20.0  subject-2
# L2S357        CTAACGCAGTCA   left palm  2009.0    3.0  17.0  subject-2
# L2S382        CTCAATGACTCA   left palm  2009.0    4.0  14.0  subject-2
# L3S378        ATCGATCTGTGG  right palm  2008.0   10.0  28.0  subject-2
# L4S63         CTCGTGGAGTAG  right palm  2009.0    1.0  20.0  subject-2
# L4S112        GCGTTACACACA  right palm  2009.0    3.0  17.0  subject-2
# L4S137        GAACTGTATCTC  right palm  2009.0    4.0  14.0  subject-2
# L5S240        CTGGACTCATAG      tongue  2008.0   10.0  28.0  subject-2
# L6S20         GAGGCTCATCAT      tongue  2009.0    1.0  20.0  subject-2
# L6S68         GATACGTCCTGA      tongue  2009.0    3.0  17.0  subject-2
# L6S93         GATTAGCACTCT      tongue  2009.0    4.0  14.0  subject-2
#
#           reported-antibiotic-usage  days-since-experiment-start
# sample-id
# L1S8                            Yes                          0.0
# L1S57                            No                         84.0
# L1S76                            No                        112.0
# L1S105                           No                        140.0
# L2S155                           No                         84.0
# L2S175                           No                        112.0
# L2S204                           No                        140.0
# L2S222                           No                        168.0
# L3S242                          Yes                          0.0
# L3S294                           No                         84.0
# L3S313                           No                        112.0
# L3S341                           No                        140.0
# L3S360                           No                        168.0
# L5S104                          Yes                          0.0
# L5S155                           No                         84.0
# L5S174                           No                        112.0
# L5S203                           No                        140.0
# L5S222                           No                        168.0
# L1S140                          Yes                          0.0
# L1S208                           No                         84.0
# L1S257                           No                        140.0
# L1S281                           No                        168.0
# L2S240                          Yes                          0.0
# L2S309                           No                         84.0
# L2S357                           No                        140.0
# L2S382                           No                        168.0
# L3S378                          Yes                          0.0
# L4S63                            No                         84.0
# L4S112                           No                        140.0
# L4S137                           No                        168.0
# L5S240                          Yes                          0.0
# L6S20                            No                         84.0
# L6S68                            No                        140.0
# L6S93                            No                        168.0

# %%
filtered_table_0, = feature_table_actions.filter_samples(
    table=table_0,
    min_frequency=1000,
    min_features=0,
    exclude_ids=False,
    filter_empty_features=True,
)
filtered_table_1, = feature_table_actions.filter_samples(
    table=filtered_table_0,
    min_frequency=0,
    min_features=0,
    metadata=sample_metadata_md,
    where='"body-site"="gut"',
    exclude_ids=True,
    filter_empty_features=True,
)
filtered_table_2, = feature_table_actions.filter_samples(
    table=filtered_table_1,
    min_frequency=0,
    min_features=0,
    metadata=sample_metadata_md,
    where='"subject"="subject-2"',
    exclude_ids=True,
    filter_empty_features=True,
)

# %%
filtered_table_2.save('/home/chris/src/provenance_py/provenance_lib/tests/data/ns_collisions2.qza')
# Out:
# '/home/chris/src/provenance_py/provenance_lib/tests/data/ns_collisions2.qza'
